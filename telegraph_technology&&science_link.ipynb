# %% [markdown]
# <a href="https://colab.research.google.com/github/doukansurel/Kod/blob/main/telegraph_technology%26%26science_link.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import bs4
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os
import time
import urllib.request
import re
import urllib3
from pandas import DataFrame
import csv
import datetime
from datetime import datetime, timedelta ,date

# %%
technology_page_link = []
science_page_link = []

# %%
def date_creator():    
  for i in range(0,222):
    lnk = "https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page={}".format(str(i))
    science_page_link.append(lnk)
  for i in range(0,214):
    lnk = "https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page={}".format(str(i))
    technology_page_link.append(lnk)

# %%
date_creator()

# %%
print(science_page_link)
print(technology_page_link)
# Out:
# ['https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=0', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=1', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=2', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=3', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=4', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=5', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=6', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=7', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=8', 'https://thetelegraph.newsbank.com/search?text=Science&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=9', 'https://thetelegraph.newsbank.com/search?text=Science&cont ...
# ['https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=0', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=1', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=2', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=3', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=4', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=5', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=6', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=7', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=8', 'https://thetelegraph.newsbank.com/search?text=Technology&content_added=&date_from=&date_to=&s_dlid=&s_ecproduct=SUB-FREE&s_ecprodtype=INSTANT&s_trackval=&s_siteloc=&s_referrer=&s_subterm=Subscription%20until%3A%2012/31/2080&s_docsbal=%20&s_subexpires=12/31/2080&s_docstart=&s_docsleft=&s_docsread=&s_username=freeusers&s_accountid=AC0121090715212929999&s_upgradeable=no&pub%5B0%5D=TELAL&page=9', 'https://thetelegraph.newsban ...

# %%
def technology_get_link_creator(url):
  html = requests.get(url).content                                                          
  soup = BeautifulSoup(html,"html.parser")
  lnk_list = soup.find("div",{"class":"view-content"}).find_all("div",{"class":"views-field views-field-text-6"})
  for i in lnk_list:
    href = i.find("a").get("href")
    if(href.startswith("https://thetelegraph.newsbank.com/")):
      pass
    else: 
      href = "https://thetelegraph.newsbank.com/"+href
    with open("telegraph_technology_Links.txt","a",encoding="utf-8") as file :
      file.write(href+"\n")

# %%
def science_get_link_creator(url):
  html = requests.get(url).content                                                          
  soup = BeautifulSoup(html,"html.parser")
  lnk_list = soup.find("div",{"class":"view-content"}).find_all("div",{"class":"views-field views-field-text-6"})
  for i in lnk_list:
    href = i.find("a").get("href")
    if(href.startswith("https://thetelegraph.newsbank.com/")):
      pass
    else: 
      href = "https://thetelegraph.newsbank.com/"+href
    with open("telegraph_science_Links.txt","a",encoding="utf-8") as file :
      file.write(href+"\n")

# %%
import concurrent
t1=time.time()
with concurrent.futures.ProcessPoolExecutor() as execut:
  b_res=[execut.submit(science_get_link_creator,i.strip()) for i in science_page_link]
print(time.time()-t1)

t2=time.time()
with concurrent.futures.ProcessPoolExecutor() as execut:
  b_res=[execut.submit(technology_get_link_creator,i.strip()) for i in technology_page_link]
print(time.time()-t2)
# Out:
# 76.86997103691101
# 76.14624977111816
